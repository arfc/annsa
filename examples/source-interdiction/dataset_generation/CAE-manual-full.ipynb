# %%
import matplotlib.pyplot as plt

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer, LabelBinarizer, Normalizer
from sklearn.model_selection import StratifiedShuffleSplit
import pickle
from numpy.random import choice
import os.path

import tensorflow as tf
import numpy as np

# %%
tf.enable_eager_execution()

# %% [markdown]
# #### Import model, training function

# %%
from annsa.model_classes import (cae_model_features,
                                 CAE,
                                 generate_random_cae_architecture,
                                 train_earlystop)

# %% [markdown]
# #### Load Dataset

# %%
dataset = np.load('../dataset_generation/hyperparametersearch_dataset_200keV_full_log10time_1000.npy')

# all_spectra = np.random.poisson(np.add(np.array(dataset.item()['sources'], dtype=float),
#                                        np.array(dataset.item()['backgrounds'], dtype=float)))

all_spectra = np.add(np.array(dataset.item()['sources'], dtype=float),
                                       np.array(dataset.item()['backgrounds'], dtype=float))

all_keys = np.array(dataset.item()['sources'], dtype=float) # background subtracted output

keys_raw = dataset.item()['keys'] # keys necessary for stratified

# %% [markdown]
# ## Train network

# %%
earlystop_errors_test = []
model_id='cae-full-final'

# %%
sss = StratifiedShuffleSplit(n_splits=5, test_size=0.25, random_state=5)

# %%
##########################
### Define Autoencoder ###
##########################

dense_nodes_encoder = (8, 16, 32, 1)

cae_features = cae_model_features(
    learning_rate=10**-4,
    encoder_trainable=True,
    batch_size=2**4,
    scaler=make_pipeline(FunctionTransformer(np.sqrt, validate=True), Normalizer(norm='max')),
    activation_function=tf.nn.relu,
    output_function=None,
    Pooling=tf.layers.MaxPooling1D,
    cnn_filters_encoder=dense_nodes_encoder,
    cnn_kernel_encoder=(16, 16, 16, 16),
    cnn_strides_encoder=(1, 1, 1, 1),
    pool_size_encoder=(16, 16, 16, 16),
    pool_strides_encoder=(2, 2, 2, 2),
    cnn_filters_decoder=dense_nodes_encoder,
    cnn_kernel_decoder=(16, 16, 16, 16),
    cnn_strides_decoder=(1, 1, 1, 1),
    )

# %%
with open('../hyperparameter_search/hyperparameter-search-results/' + model_id, 'wb+') as f:
    pickle.dump(cae_features,f)

# %%
cae_optimizer = tf.train.AdamOptimizer(cae_features.learning_rate)

k_folds_errors = []

cae_models = []

k = 0

for train_index, test_index in sss.split(all_spectra, keys_raw):

    # reset model on each iteration
    cae_model = CAE(cae_features)
    cae_model.scaler.fit(all_spectra[train_index])

    ##########################
    #### Train Autoencoder ###
    ##########################
    not_learning_threshold=1.0

    costfunction_errors_cae_tmp, earlystop_errors_cae_tmp = train_earlystop(
        training_data=all_spectra[train_index],
        training_keys=all_keys[train_index],
        testing_data=all_spectra[test_index],
        testing_keys=all_keys[test_index],
        model=cae_model,
        optimizer=cae_optimizer,
        num_epochs=500,
        obj_cost=cae_model.mse,
        earlystop_cost_fn=cae_model.mse,
        earlystop_patience=10,
        verbose=True,
        fit_batch_verbose=1,
        data_augmentation=cae_model.poisson_data_augmentation)

    k_folds_errors.append(earlystop_errors_cae_tmp)
    cae_models.append(cae_model)
    cae_model.save_weights('./final-models/'+model_id+'_pretrained'+'_checkpoint_'+str(k))
    k += 1
# Out:
# Epoch 1: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 2: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 3: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 4: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 5: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 6: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 7: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 8: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 9: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 10: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 11: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 12: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 13: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 14: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 15: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 16: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 17: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 18: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 19: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 20: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 21: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 22: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 23: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 24: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 25: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 26: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 27: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 28: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 29: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 30: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 31: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 32: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 33: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 34: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 35: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 36: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 37: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 38: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 39: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 40: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 41: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 42: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 43: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 44: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 45: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 46: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 47: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 48: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 49: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 50: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 51: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 52: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 53: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 54: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 55: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 56: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 57: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 58: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 59: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 60: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 61: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 62: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 63: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 64: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 65: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 66: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 67: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 68: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 69: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 70: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 71: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 72: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 73: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 74: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 75: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 76: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 77: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 78: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 79: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 80: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 81: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 82: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 83: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 84: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 85: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 86: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 87: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 88: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 89: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 90: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 91: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 92: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 93: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 94: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 95: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 96: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 97: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 98: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 99: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 100: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 101: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 102: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 103: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 104: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 105: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 106: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 107: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 108: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 109: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 110: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 111: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 112: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 113: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 114: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 115: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Test error at early stop: Objectives fctn: 0.00 Early stopfctn: 0.00
# Epoch 1: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 2: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 3: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 4: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 5: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 6: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 7: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 8: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 9: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 10: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 11: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 12: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 13: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 14: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 15: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 16: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 17: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 18: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Test error at early stop: Objectives fctn: 0.03 Early stopfctn: 0.03
# Epoch 1: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 2: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 3: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 4: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 5: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 6: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 7: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 8: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 9: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 10: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 11: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 12: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 13: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 14: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 15: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 16: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 17: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 18: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Test error at early stop: Objectives fctn: 0.03 Early stopfctn: 0.03
# Epoch 1: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 2: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 3: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 4: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 5: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 6: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 7: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 8: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 9: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 10: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 11: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 12: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 13: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 14: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 15: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 16: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 17: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 18: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 19: CostFunc loss: 0.00 0.01, EarlyStop loss: 0.00 0.01
# Epoch 20: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 21: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 22: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 23: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 24: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 25: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 26: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 27: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 28: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 29: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 30: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 31: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 32: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 33: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 34: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 35: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 36: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 37: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 38: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 39: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 40: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 41: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 42: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 43: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 44: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 45: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 46: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 47: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 48: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 49: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 50: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 51: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 52: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 53: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 54: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 55: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 56: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 57: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 58: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 59: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 60: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 61: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 62: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 63: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 64: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 65: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 66: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 67: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 68: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 69: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 70: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 71: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 72: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 73: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 74: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 75: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 76: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 77: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 78: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 79: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 80: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 81: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 82: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 83: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 84: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 85: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 86: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 87: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 88: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 89: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 90: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 91: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 92: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 93: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 94: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 95: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 96: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 97: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 98: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 99: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 100: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 101: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 102: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 103: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 104: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 105: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 106: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 107: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 108: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 109: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 110: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 111: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 112: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 113: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 114: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 115: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 116: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 117: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 118: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 119: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 120: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 121: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 122: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 123: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 124: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 125: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 126: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 127: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 128: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 129: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 130: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 131: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 132: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 133: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 134: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 135: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 136: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 137: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 138: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 139: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Epoch 140: CostFunc loss: 0.00 0.00, EarlyStop loss: 0.00 0.00
# Test error at early stop: Objectives fctn: 0.00 Early stopfctn: 0.00
# Epoch 1: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 2: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 3: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 4: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 5: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 6: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 7: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 8: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03
# Epoch 9: CostFunc loss: 0.00 0.03, EarlyStop loss: 0.00 0.03

# %% [markdown]
# ### Load model

# %%
cae_models = {}


for index in range(4):
    cae_models[index] = CAE(cae_features)
    cae_models[index].load_weights('./final-models/'+model_id+'_pretrained_checkpoint_'+str(index))

# %% [markdown]
# ### Run example data

# %%
index = 15007 # background
# index = 17056

print('isotope: ' + keys_raw[index])
plt.figure(figsize=(10,6))
plt.plot(cae_models[1].scaler.transform(all_spectra[index:index+1])[0], label = 'orig data')
plt.plot(cae_models[1].scaler.transform(all_keys[index:index+1])[0], label = 'orig keys')

for model_index in cae_models:
    tmp_model = cae_models[model_index]    
    plt.plot(tmp_model.decoder(tmp_model.encoder(all_spectra[index:index+1])).numpy()[0], label = str(tmp_model)+' output')
    plt.legend()

plt.figure(figsize=(10,6))    
for model_index in cae_models:
    tmp_model = cae_models[model_index]    
    plt.plot(tmp_model.encoder(all_spectra[index:index+1]).numpy()[0])
# Out:
# isotope: background

# %% [raw]
# checkpoint_directory = "final-models"
# dae_model.save_weights('./final-models/VANILLA-DAE_draft_shielded_dataset_100_fwhm6_log10p')

# %%
from sklearn.decomposition import PCA

# %%
dae_model_bs_sqrt = DAE(dae_features)
dae_model_bs_sqrt.load_weights('./final-models/BS-DAE_draft_shielded_dataset_100_fwhm6_sqrt')

dae_model_bs_log10p = DAE(dae_features)
dae_model_bs_log10p.load_weights('./final-models/BS-DAE_draft_shielded_dataset_100_fwhm6_log10p')

dae_model_vanilla_sqrt = DAE(dae_features)
dae_model_vanilla_sqrt.load_weights('./final-models/VANILLA-DAE_draft_shielded_dataset_100_fwhm6_sqrt')

dae_model_vanilla_log10p = DAE(dae_features)
dae_model_vanilla_log10p.load_weights('./final-models/VANILLA-DAE_draft_shielded_dataset_100_fwhm6_log10p')

# %% [markdown]
# # Visualize 2D PCA of BS-DAE outputs

# %%
def visualize_2d_PCA(model, dataset, plot=False):
    pca = PCA(n_components = 2)
    pca.fit(model.encoder(dataset).numpy())
    for k in range(100):
        for i in range(10):
            pca_vals = pca.transform(model.encoder(dataset[300*i+k:300*i+k+1]).numpy())[0][0:2]
            if plot == True:
                plt.scatter(pca_vals[0], pca_vals[1], label = str(i))
    return pca_vals

# %%
plt.figure(figsize=(10,10))

# BS-DAE-log10
plt.subplot(221)
visualize_2d_PCA(dae_model_bs_log10p, all_spectra, True)
plt.title('BS-DAE-log10')
plt.xlim([])

# BS-DAE-sqrt
plt.subplot(222)
visualize_2d_PCA(dae_model_bs_sqrt, all_spectra, True)
plt.title('BS-DAE-sqrt')

# vanilla-DAE-log10
plt.subplot(223)
visualize_2d_PCA(dae_model_vanilla_log10p, all_spectra, True)
plt.title('vanilla-DAE-log10')

# vanilla-DAE-sqrt
plt.subplot(224)
visualize_2d_PCA(dae_model_vanilla_sqrt, all_spectra, True)
plt.title('vanilla-DAE-sqrt')

#plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
#                    wspace=0.35)
# Out:
# Text(0.5,1,'vanilla-DAE-sqrt')

# %% [markdown]
# ### Visualize 2D PCA of preprocessed spectra

# %%
plt.figure(figsize=(10,5))

# log10
#plt.subplot(121)
plt.subplot(121)
pca = PCA(n_components=2)
pca.fit(np.log1p(all_spectra))
for k in range(100):
    for i in range(10):
        pca_vals = pca.transform(np.log1p(all_spectra[300*i+k:300*i+k+1]))[0][0:2]
        plt.scatter(pca_vals[0],pca_vals[1], label=str(i))
plt.title('log10')

# BS-DAE-sqrt
plt.subplot(122)
pca = PCA(n_components=2)
pca.fit(np.sqrt(all_spectra))
for k in range(100):
    for i in range(10):
        pca_vals = pca.transform(np.sqrt(all_spectra[300*i+k:300*i+k+1]))[0][0:2]
        plt.scatter(pca_vals[0],pca_vals[1], label=str(i))
plt.title('sqrt')
# Out:
# Text(0.5,1,'sqrt')

# %% [markdown]
# ### Comparing output

# %%
all_models = [dae_model_bs_log10p,
              dae_model_bs_sqrt,
              dae_model_vanilla_log10p,
              dae_model_vanilla_sqrt]

# %%
tmp_model

# %%
index = 850

plt.figure(figsize=(10,6))
for tmp_model in all_models:
    plt.plot(tmp_model.scaler.transform(all_source_spectra[index:index+1])[0], label = str(tmp_model)+' orig data')
    plt.plot(tmp_model.decoder(tmp_model.encoder(all_spectra[index:index+1])).numpy()[0], label = str(tmp_model)+' output')
plt.ylim([-10,10])
plt.legend()

# %% [markdown]
# # Use a dataset outside training

# %%
tmp_model = dae_model

index = 407

plt.plot(tmp_model.scaler.transform(all_spectra_TEST[index:index+1])[0], label='TEST DATA')
plt.plot(tmp_model.decoder(tmp_model.encoder(all_spectra_TEST[index:index+1])).numpy()[0], label='Reconstructed')
plt.ylim([-10,10])
plt.legend()

# %%
pca = PCA(n_components=2)
pca.fit(np.sqrt(all_spectra_TEST))

for k in range(50):
    for i in range(10):
        pca_vals = pca.transform(np.sqrt(all_spectra_TEST[125*i+k:125*i+k+1]))[0][0:2]
        plt.scatter(pca_vals[0], pca_vals[1], label=all_keys_TEST[i])
#plt.legend()
# all_spectra.shape

# %%
pca = PCA(n_components=2)
pca.fit(np.log1p(all_spectra_TEST))

for k in range(50):
    for i in range(10):
        pca_vals = pca.transform(np.log1p(all_spectra_TEST[125*i+k:125*i+k+1]))[0][0:2]
        plt.scatter(pca_vals[0], pca_vals[1], label=all_keys_TEST[i])
#plt.legend()
# all_spectra.shape

# %%
tmp_model = dae_model_vanilla_log10p

pca = PCA(n_components=2)
pca.fit(tmp_model.encoder(all_spectra_TEST).numpy())

for k in range(50):
    for i in range(10):
        pca_vals = pca.transform(tmp_model.encoder(all_spectra_TEST[125*i+k:125*i+k+1]).numpy())[0][0:2]
        plt.scatter(pca_vals[0], pca_vals[1], label=all_keys_TEST[i])
#plt.legend()
# all_spectra.shape
