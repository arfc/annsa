# %%
GPU_device_id = str(4)
model_id_save_as = 'learningcurve-cae-easy-dataaug-final'
architecture_id = '../hyperparameter_search/hyperparameter-search-results/cae-easy-final'
model_class_id = 'CNN1D'
testing_dataset_id = '../../source-interdiction/dataset_generation/validation_dataset_200keV_log10time_10.npy'
data_augmentation = True
cnn_features_filename = '../hyperparameter_search/hyperparameter-search-results/CNN-kfoldseasy-final-1_14'

# default 
fit_batch_verbose = 10
weight_id = '../final_training_notebooks/final-models/cae-easy-final_pretrained_checkpoint_0'
training_dataset_id = None
difficulty_setting = 'easy'
num_epochs = 5000


total_networks = 5
earlystop_patience = 100

# %%
from learningcurvetest import training_wrapper

# %%
training_wrapper(GPU_device_id = GPU_device_id,
                 model_id_save_as = model_id_save_as,
                 architecture_id = architecture_id,
                 model_class_id = model_class_id,
                 testing_dataset_id = testing_dataset_id,
                 data_augmentation = data_augmentation,
                 weight_id = weight_id,
                 total_networks=total_networks,
                 fit_batch_verbose=fit_batch_verbose,
                 training_dataset_id = training_dataset_id,
                 num_epochs=num_epochs,
                 difficulty_setting = difficulty_setting,
                 earlystop_patience=earlystop_patience,
                 cnn_features_filename=cnn_features_filename,
                 dense_nodes=[],)
# Out:
# indicies dropped: []
# Epoch 10: CostFunc loss: 0.00 3.46, EarlyStop loss: 0.00 0.96
# Epoch 20: CostFunc loss: 0.00 3.41, EarlyStop loss: 0.00 0.95
# Epoch 30: CostFunc loss: 0.00 3.40, EarlyStop loss: 0.00 0.96
# Epoch 40: CostFunc loss: 0.00 3.39, EarlyStop loss: 0.00 0.98
# Epoch 50: CostFunc loss: 0.00 3.39, EarlyStop loss: 0.00 0.97
# Epoch 60: CostFunc loss: 0.00 3.39, EarlyStop loss: 0.00 0.96
# Epoch 70: CostFunc loss: 0.00 3.39, EarlyStop loss: 0.00 0.97
# Epoch 80: CostFunc loss: 0.00 3.39, EarlyStop loss: 0.00 0.96
# Epoch 90: CostFunc loss: 0.00 3.39, EarlyStop loss: 0.00 0.97
# Epoch 100: CostFunc loss: 0.00 3.39, EarlyStop loss: 0.00 0.97
# Epoch 110: CostFunc loss: 0.00 3.39, EarlyStop loss: 0.00 0.96
# Epoch 120: CostFunc loss: 0.00 3.39, EarlyStop loss: 0.00 0.96
# Test error at early stop: Objectives fctn: 3.41 Early stopfctn: 3.41
# Epoch 10: CostFunc loss: 0.00 3.43, EarlyStop loss: 0.00 0.97
# Epoch 20: CostFunc loss: 0.00 3.42, EarlyStop loss: 0.00 0.97
# ...

# %% [raw]
# Epoch 10: CostFunc loss: 0.00 3.49, EarlyStop loss: 0.00 0.97
# Epoch 20: CostFunc loss: 0.00 3.46, EarlyStop loss: 0.00 0.97
# Epoch 30: CostFunc loss: 0.00 3.44, EarlyStop loss: 0.00 0.97
# Epoch 40: CostFunc loss: 0.00 3.43, EarlyStop loss: 0.00 0.97
# Epoch 50: CostFunc loss: 0.00 3.42, EarlyStop loss: 0.00 0.97
