# %%
GPU_device_id = str(6)
model_id_save_as = 'learningcurve-dae-easy-dataaug-final'
architecture_id = '../hyperparameter_search/hyperparameter-search-results/dae-easy-final'
model_class_id = 'DNN'
testing_dataset_id = '../../source-interdiction/dataset_generation/validation_dataset_200keV_log10time_10.npy'
data_augmentation = True
dnn_features_filename = '../hyperparameter_search/hyperparameter-search-results/DNN-kfoldseasy-final-5_11_dae_features'

# default 
fit_batch_verbose = 10
weight_id = '../final_training_notebooks/final-models/dae-easy-final_pretrained_checkpoint_0'
training_dataset_id = None
difficulty_setting = 'easy'
num_epochs = 5000

total_networks = 5
earlystop_patience = 100

# %%
from learningcurvetest import training_wrapper

# %%
training_wrapper(GPU_device_id = GPU_device_id,
                 model_id_save_as = model_id_save_as,
                 architecture_id = architecture_id,
                 model_class_id = model_class_id,
                 testing_dataset_id = testing_dataset_id,
                 data_augmentation = data_augmentation,
                 weight_id = weight_id,
                 total_networks=total_networks,
                 fit_batch_verbose=fit_batch_verbose,
                 training_dataset_id = training_dataset_id,
                 num_epochs=num_epochs,
                 difficulty_setting = difficulty_setting,
                 earlystop_patience=earlystop_patience,
                 dnn_features_filename=dnn_features_filename,
                 dense_nodes=[],)
# Out:
# indicies dropped: []
# INFO:tensorflow:Scale of 0 disables regularizer.
# Epoch 10: CostFunc loss: 0.00 19.69, EarlyStop loss: 0.00 0.95
# Epoch 20: CostFunc loss: 0.00 16.39, EarlyStop loss: 0.00 0.93
# Epoch 30: CostFunc loss: 0.00 14.76, EarlyStop loss: 0.00 0.93
# Epoch 40: CostFunc loss: 0.00 13.50, EarlyStop loss: 0.00 0.94
# Epoch 50: CostFunc loss: 0.00 12.49, EarlyStop loss: 0.00 0.95
# Epoch 60: CostFunc loss: 0.00 11.66, EarlyStop loss: 0.00 0.91
# Epoch 70: CostFunc loss: 0.00 11.13, EarlyStop loss: 0.00 0.89
# Epoch 80: CostFunc loss: 0.00 10.77, EarlyStop loss: 0.00 0.88
# Epoch 90: CostFunc loss: 0.00 10.53, EarlyStop loss: 0.00 0.87
# Epoch 100: CostFunc loss: 0.00 10.32, EarlyStop loss: 0.00 0.83
# Epoch 110: CostFunc loss: 0.00 10.13, EarlyStop loss: 0.00 0.83
# Epoch 120: CostFunc loss: 0.00 9.95, EarlyStop loss: 0.00 0.81
# Epoch 130: CostFunc loss: 0.00 9.79, EarlyStop loss: 0.00 0.83
# Epoch 140: CostFunc loss: 0.00 9.65, EarlyStop loss: 0.00 0.83
# ...

# %% [raw]
# indicies dropped: []
# INFO:tensorflow:Scale of 0 disables regularizer.
# Epoch 10: CostFunc loss: 0.00 20.02, EarlyStop loss: 0.00 0.96
# Epoch 20: CostFunc loss: 0.00 17.31, EarlyStop loss: 0.00 0.98
# Epoch 30: CostFunc loss: 0.00 15.59, EarlyStop loss: 0.00 0.96
# Epoch 40: CostFunc loss: 0.00 14.51, EarlyStop loss: 0.00 0.96
# Epoch 50: CostFunc loss: 0.00 13.52, EarlyStop loss: 0.00 0.92
# Epoch 60: CostFunc loss: 0.00 12.76, EarlyStop loss: 0.00 0.91
# Epoch 70: CostFunc loss: 0.00 12.11, EarlyStop loss: 0.00 0.87
