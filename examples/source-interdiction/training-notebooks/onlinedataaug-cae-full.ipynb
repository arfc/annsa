# %%
GPU_device_id = str(5)
model_id_save_as = 'learningcurve-cae-full-dataaug-final'
architecture_id = '../hyperparameter_search/hyperparameter-search-results/cae-full-final'
model_class_id = 'CNN1D'
testing_dataset_id = '../../source-interdiction/dataset_generation/validation_dataset_full_200keV_log10time_10.npy'
data_augmentation = True
cnn_features_filename = '../hyperparameter_search/hyperparameter-search-results/CNN-kfoldsfull-final-3_5'

# default 
fit_batch_verbose = 1
weight_id = '../final_training_notebooks/final-models/cae-full-final_pretrained_checkpoint_0'
training_dataset_id = None
difficulty_setting = 'full'

total_networks = 5
earlystop_patience = 50

# %%
from learningcurvetest import training_wrapper

# %%
training_wrapper(GPU_device_id = GPU_device_id,
                 model_id_save_as = model_id_save_as,
                 architecture_id = architecture_id,
                 model_class_id = model_class_id,
                 testing_dataset_id = testing_dataset_id,
                 data_augmentation = data_augmentation,
                 weight_id = weight_id,
                 total_networks=total_networks,
                 fit_batch_verbose=fit_batch_verbose,
                 training_dataset_id = training_dataset_id,
                 difficulty_setting = difficulty_setting,
                 earlystop_patience=earlystop_patience,
                 cnn_features_filename=cnn_features_filename,
                 dense_nodes=[],)
# Out:
# indicies dropped: [552 553 554 555 556 557 564 565 566 582 583 584 585 586 587 594 595 596
#  612 613 614 615 616 617 624 625 626 642 643 644 645 646 647 654 655 656
#  672 673 674 675 676 677 684 685 686 702 703 704 705 706 707 714 715 716]
# Epoch 1: CostFunc loss: 0.00 3.29, EarlyStop loss: 0.00 0.94
# Epoch 2: CostFunc loss: 0.00 3.16, EarlyStop loss: 0.00 0.89
# Epoch 3: CostFunc loss: 0.00 2.95, EarlyStop loss: 0.00 0.87
# Epoch 4: CostFunc loss: 0.00 2.75, EarlyStop loss: 0.00 0.82
# Epoch 5: CostFunc loss: 0.00 2.56, EarlyStop loss: 0.00 0.81
# Epoch 6: CostFunc loss: 0.00 2.43, EarlyStop loss: 0.00 0.82
# Epoch 7: CostFunc loss: 0.00 2.35, EarlyStop loss: 0.00 0.78
# Epoch 8: CostFunc loss: 0.00 2.31, EarlyStop loss: 0.00 0.75
# Epoch 9: CostFunc loss: 0.00 2.22, EarlyStop loss: 0.00 0.74
# Epoch 10: CostFunc loss: 0.00 2.17, EarlyStop loss: 0.00 0.75
# Epoch 11: CostFunc loss: 0.00 2.12, EarlyStop loss: 0.00 0.66
# ...

# %% [raw]
# Epoch 1: CostFunc loss: 0.00 3.36, EarlyStop loss: 0.00 0.97
# Epoch 2: CostFunc loss: 0.00 3.23, EarlyStop loss: 0.00 0.91
# Epoch 3: CostFunc loss: 0.00 3.09, EarlyStop loss: 0.00 0.90
# Epoch 4: CostFunc loss: 0.00 2.97, EarlyStop loss: 0.00 0.86
# Epoch 5: CostFunc loss: 0.00 2.85, EarlyStop loss: 0.00 0.83
# Epoch 6: CostFunc loss: 0.00 2.73, EarlyStop loss: 0.00 0.83
# Epoch 7: CostFunc loss: 0.00 2.63, EarlyStop loss: 0.00 0.80
# Epoch 8: CostFunc loss: 0.00 2.53, EarlyStop loss: 0.00 0.77
